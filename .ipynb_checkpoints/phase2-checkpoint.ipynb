# %% [markdown]
# INFO 2950 - Phase 2
#
# Research Question: Can we predict the GDP per capita of the United States based on Consumer Price Index (CPI) inflation rates, wages and income inequality between men and women as well as various ethnic groups?
#
# In this assignment we're trying to discover if there is a correlation between GDP per capita, inflation, wages, and income distribution across gender and race. We'll be looking at the relationship between all of these variables and attempting to capture what trends have been going on in the U.S during the years of 1973-2022.

# %% [markdown]
# Data Description:
#
# Sources:
# Inflation: https://www.kaggle.com/datasets/neelgajare/usa-cpi-inflation-from-19132022
# Columns:
# -- Index: Standard indexing, starts at 0 marks the index of each row
# -- Year: One full year per row, starts at 1913 and goes until 2022
# -- Jan: CPI index in the month of January
# -- Feb: CPI index in the month of February
# -- Mar: CPI index in the month of March
# -- Apr: CPI index in the month of April
# -- May: CPI index in the month of May
# -- Jun: CPI index in the month of June
# -- Jul: CPI index in the month of July
# -- Aug: CPI index in the month of August
# -- Sep: CPI index in the month of September
# -- Oct: CPI index in the month of October
# -- Nov: CPI index in the month of November
# -- Dec: CPI index in the month of December
#
# Why was this dataset created?:
# To track inflation changes over the years by using Consumer Price Index, a measure of the average change in prices paid by consumers for a market basket of goods and services.
#
# Who funded the creation of this dataset?:
# It appears to have been created independently by a Kaggle user by the name of "Neel Gajare."
#
# What processes might have influenced what data was observed and recorded and what was not?:
# The user attributed their source to be the U.S Bureau of Labor Statistics which we can hopefully assume is quite comprehensive and thorough. Therefore, it seems this dataset is should be representative and whole unless they somehow collected it wrong.
#
# If people are involved, were they aware of the data collection and if so, what purpose did they expect the data to be used for?:
# This data has nothing to do with any specific individuals. It is CPI data that the Kaggle owner, Gajare, attributes to the U.S Bureau of Labor Statistics whose function it is to make this data available, so they likely expected and hoped for their data to be used in projects like this.
#
#
# Wages: https://www.kaggle.com/datasets/asaniczka/poverty-level-wages-in-the-usa-dataset-1973-2022
# Columns:
# -- Year: one full year per row, starts at 1973 and ends at 2022
# -- annual_poverty-level_wage: Annual poverty level wage in nominal dollars
# -- hourly_poverty-level_wage: Hourly poverty level wage for full-time year-round workers
# -- 0-75%_of_poverty_wages: Share of workers earning 75-100% of the poverty-level wage
# -- 75-100%_of_poverty_wages: Share of workers earning 75-100% of the poverty-level wage
# -- share_below_poverty_wages: Share of workers earning less than or equal to the poverty-level wage
# -- 100-125%_of_poverty_wages: Share of workers earning 100-125% of the poverty-level wage
# -- 200-300%_of_poverty_wages: Share of workers earning 200-300% of the poverty-level wage
# -- 300%+_of_poverty_wages: Share of workers earning above 300% of the poverty-level wage
# -- men_0-75%_of_poverty_wages: Share of men earning 0-75% of the poverty-level wage
# -- men_75-100%_of_poverty_wages: Share of men earning 75-100% of the poverty-level wage
# -- men_share_below_poverty_wages: Share of men earning below the poverty-level wage
# -- men_100-125%_of_poverty_wages: Share of men earning 100-125% of the poverty-level wage
# -- men_125-200%_of_poverty_wages: Share of men earning 125-200% of the poverty-level wage
# -- men_200-300%_of_poverty_wages: Share of men earning 200-300% of the poverty-level wage
# -- men_300%+_of_poverty_wages: Share of men earning above 300% of the poverty-level wage
# -- women_0-75%_of_poverty_wages: Share of women earning 0-75% of the poverty-level wage
# -- women_75-100%_of_poverty_wages: Share of women earning 75-100% of the poverty-level wage
# -- women_share_below_poverty_wages: Share of women earning below the poverty-level wage
# -- women_100-125%_of_poverty_wages: Share of women earning 100-125% of the poverty-level wage
# -- women_125-200%_of_poverty_wages: Share of women earning 125-200% of the poverty-level wage
# -- women_200-300%_of_poverty_wages: Share of women earning 200-300% of the poverty-level wage
# -- women_300%+_of_poverty_wages: Share of women earning above 300% of the poverty-level wage
# -- white_share_below_poverty_wages: Share of white workers earning below the poverty-level wage
# -- white_men_share_below_poverty_wages: Share of white men earning below the poverty-level wage
# -- white_women_share_below_poverty_wages: Share of white women earning below the poverty-level wage
# -- black_share_below_poverty_wages: Share of black workers earning below the poverty-level wage
# -- black_men_share_below_poverty_wages: Share of black men earning below the poverty-level wage
# -- black_women_share_below_poverty_wages: Share of black women earning below the poverty-level wage
# -- hispanic_share_below_poverty_wages: Share of Hispanic workers earning below the poverty-level wage
# -- hispanic_men_share_below_poverty_wages: Share of Hispanic men earning below the poverty-level wage
# -- hispanic_women_share_below_poverty_wages: Share of Hispanic women earning below the poverty-level wage
#
# Why was this dataset created?:
# To understand wages, how they've changed over the years and how they are distributed vertically (how many people are making very little) and how they are distributed horizontally (how are wages different between various groups of people).
#
# Who funded the creation of this dataset?:
# This dataset appears to have been created by independent Kaggle user: asaniczka, who claims to be Kaggle expert and data engineer in Sri Lanka. This user has also created many other datastets like "USA Wage Comparison for College vs. High School," "150K TMDb TV Shows," etc.
#
# What processes might have influenced what data was observed and recorded and what was not?
# The Kaggle owner attributes the data to the Economic Policy Institute’s State of Working America Data Library. Unfortunately, we did not have tiem to investigate the reputability of this organization. At a brief first glance, however, they do not seem to be illegitimate. In this project, we will operate on the assumption that the data is valid.
#
#
# GDP: Handmade table using World Bank data
# We made this dataset ourself so not much explanation is required. A quick Google query of "US gdp per capita" returns an interactive graph which lets you see the numbers over the years. We simply looked at this data and entered each data point by hand into a spreadsheet. The graph data was attributed to the World Bank which is very well-known and reputable so we believe the data is valid.
#
#
# FOR STEPS ON PREPROCESSING AND CLEANING, LOOK BELOW. We thought it prudent to have this section, "Data Description," dedicated to talking about the datasets in their original form, where we found them, etc. The below sections cover all data cleaning and manipulation to create the analysis ready dataset in full detail.

# %% [markdown]
# Data Cleaning:
#
# Step 1: Aligning time frames
# We want all the datasets to start at the same year and end at the same year. Currently, the wages data is 1973-2022, the inflation data 1913-2022, and the GDP data 1973-2021. We want all datasets to be 1973-2021 so that they are aligned.
#
# Step 2: Averaging inflation data
# Currently, the inflation data has the CPI month-by-month for each year. But we are not doing analysis on a month-by-month basis. We are doing in on a year-by-year basis. So, we want to average the month-by-month values so we have an annual CPI for each year.
#
# Step 3: Dropping unncessary wage data
# For the purposes of this assignment, we want to capture the more notable and extreme trends. We're not really trying to analyze lower middle-class to middle-class wages. We want to capture the large disparities and the significant trends. To accomplish this, we'll retain the columns: annual_poverty-level_wage, hourly_poverty-level_wage, share_below_poverty_wages, 300%+_of_poverty_wages, men_share_below_poverty_wages, men_300%+_of_poverty_wages, women_share_below_poverty_wages, women_300%+_of_poverty_wages, white_share_below_poverty_wages,white_men_share_below_poverty_wages, white_women_share_below_poverty_wages, black_share_below_poverty_wages, black_men_share_below_poverty_wages, black_women_share_below_poverty_wages, hispanic_share_below_poverty_wages, hispanic_men_share_below_poverty_wages, hispanic_women_share_below_poverty_wages. It is our group's belief that these columns capture the most important insights.
#
# Step 4: Create analysis ready dataset
# Combine our cleaned datasets into our final table now that they are cleaned and processed.
#
# These are the generally important edits we must make. Throughout the code you may see some smaller preprocessing being done whcih we'll explain, but these are the overall broad strokes.

# %%
import numpy as np 
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt 
import duckdb

# %%
inflation_data = pd.read_csv('inflation.csv')
inflation_data
# Out:
#      Unnamed: 0    Year      Jan      Feb      Mar      Apr      May      Jun  \
# 0             0  1913.0    9.800    9.800    9.800    9.800    9.700    9.800
# 1             1  1914.0   10.000    9.900    9.900    9.800    9.900    9.900
# 2             2  1915.0   10.100   10.000    9.900   10.000   10.100   10.100
# 3             3  1916.0   10.400   10.400   10.500   10.600   10.700   10.800
# 4             4  1917.0   11.700   12.000   12.000   12.600   12.800   13.000
# ..          ...     ...      ...      ...      ...      ...      ...      ...
# 105         105  2018.0  247.867  248.991  249.554  250.546  251.588  251.989
# 106         106  2019.0  251.712  252.776  254.202  255.548  256.092  256.143
# 107         107  2020.0  257.971  258.678  258.115  256.389  256.394  257.797
# 108         108  2021.0  261.582  263.014  264.877  267.054  269.195  271.696
# 109         109  2022.0  281.148  283.716  287.504  289.109      NaN      NaN
#
# ...

# %%
wage_data = pd.read_csv('poverty_level_wages.csv')
wage_data
# Out:
#     year  annual_poverty-level_wage  hourly_poverty-level_wage  \
# 0   2022                      27733                      13.33
# 1   2021                      25688                      12.35
# 2   2020                      24544                      11.80
# 3   2019                      24242                      11.65
# 4   2018                      23809                      11.45
# 5   2017                      23244                      11.18
# 6   2016                      22755                      10.94
# 7   2015                      22464                      10.80
# 8   2014                      22422                      10.78
# 9   2013                      22048                      10.60
# 10  2012                      21715                      10.44
# 11  2011                      21278                      10.23
# 12  2010                      20634                       9.92
# 13  2009                      20293                       9.76
# ...

# %%
gdp_data = pd.read_csv('gdp_per_capita.csv')
gdp_data
# Out:
#     Year  GDP_Per_Capita
# 0   1973         6726.36
# 1   1974         7225.69
# 2   1975         7801.46
# 3   1976         8592.25
# 4   1977         9452.58
# 5   1978        10564.95
# 6   1979        11674.18
# 7   1980        12574.79
# 8   1981        13976.11
# 9   1982        14433.79
# 10  1983        15543.89
# 11  1984        17121.23
# 12  1985        18236.83
# 13  1986        19071.23
# 14  1987        20038.94
# 15  1988        21417.07
# 16  1989        22857.15
# 17  1990        23888.60
# 18  1991        24342.26
# 19  1992        25418.99
# 20  1993        26387.29
# 21  1994        27694.85
# 22  1995        28690.88
# 23  1996        29967.71
# 24  1997        31459.14
# 25  1998        32853.68
# 26  1999        34515.39
# 27  2000        36329.96
# 28  2001        37133.62
# 29  2002        37997.76
# 30  2003        39490.27
# 31  2004        41724.63
# 32  2005        44123.41
# 33  2006        46302.00
# 34  2007        48050.22
# 35  2008        48570.05
# ...

# %% [markdown]
# Data Cleaning - Step 1

# %%
# INFLATION DATA

# First, change the type of the Year column from float to int
inflation_data['Year'] = inflation_data['Year'].astype(int)

# Then drop rows not in the interval of 1973-2021
inflation_data = inflation_data[(inflation_data['Year'] >= 1973) & (inflation_data['Year'] <= 2021)]

# While we're at it, we'll also drop the "Unnamed: 0" column that was read in weirdly since we don't want it
inflation_data = inflation_data.drop('Unnamed: 0', axis=1)

inflation_data
# Out:
#      Year      Jan      Feb      Mar      Apr      May      Jun      Jul  \
# 60   1973   42.600   42.900   43.300   43.600   43.900   44.200   44.300
# 61   1974   46.600   47.200   47.800   48.000   48.600   49.000   49.400
# 62   1975   52.100   52.500   52.700   52.900   53.200   53.600   54.200
# 63   1976   55.600   55.800   55.900   56.100   56.500   56.800   57.100
# 64   1977   58.500   59.100   59.500   60.000   60.300   60.700   61.000
# 65   1978   62.500   62.900   63.400   63.900   64.500   65.200   65.700
# 66   1979   68.300   69.100   69.800   70.600   71.500   72.300   73.100
# 67   1980   77.800   78.900   80.100   81.000   81.800   82.700   82.700
# 68   1981   87.000   87.900   88.500   89.100   89.800   90.600   91.600
# 69   1982   94.300   94.600   94.500   94.900   95.800   97.000   97.500
# 70   1983   97.800   97.900   97.900   98.600   99.200   99.500   99.900
# 71   1984  101.900  102.400  102.600  103.100  103.400  103.700  104.100
# ...

# %%
# WAGE DATA

# First, let's just reverse the years, because currently, its starting with 2022 and then going to 1973
wage_data.sort_values(by='year', ascending=True, inplace=True)

# Then, we just have to delete the 2022 row because it already starts at 1973
wage_data = wage_data[wage_data['year'] != 2022]

# Let's also just rename 'year' to 'Year' since we're using uppercase for other dataframes
wage_data= wage_data.rename(columns={'year' : 'Year'})

wage_data
# Out:
#     Year  annual_poverty-level_wage  hourly_poverty-level_wage  \
# 49  1973                       4701                       2.26
# 48  1974                       5158                       2.48
# 47  1975                       5595                       2.69
# 46  1976                       5914                       2.84
# 45  1977                       6284                       3.02
# 44  1978                       6718                       3.23
# 43  1979                       7360                       3.54
# 42  1980                       8181                       3.93
# 41  1981                       8956                       4.31
# 40  1982                       9499                       4.57
# 39  1983                       9901                       4.76
# 38  1984                      10317                       4.96
# 37  1985                      10670                       5.13
# 36  1986                      10858                       5.22
# ...

# %%
# GDP DATA: already starts at 1973 and ends at 2021 so no editing is needed

# %% [markdown]
# Data Cleaning - Step 2

# %%
# First, we'll create the Annual_Rate column
columns_to_average = inflation_data.columns[1:]
inflation_data['Annual_CPI'] = inflation_data[columns_to_average].mean(axis=1)

# Drop all the month columns since they are no longer necessary
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
inflation_data = inflation_data.drop(columns=months)

# Round to two decimal places
inflation_data['Annual_CPI'] = inflation_data['Annual_CPI'].round(2)

inflation_data
# Out:
#      Year  Annual_CPI
# 60   1973       44.40
# 61   1974       49.31
# 62   1975       53.82
# 63   1976       56.91
# 64   1977       60.61
# 65   1978       65.23
# 66   1979       72.58
# 67   1980       82.41
# 68   1981       90.92
# 69   1982       96.50
# 70   1983       99.60
# 71   1984      103.88
# 72   1985      107.57
# 73   1986      109.61
# 74   1987      113.62
# 75   1988      118.26
# 76   1989      123.97
# 77   1990      130.66
# 78   1991      136.19
# 79   1992      140.32
# 80   1993      144.46
# 81   1994      148.23
# 82   1995      152.38
# 83   1996      156.85
# 84   1997      160.52
# 85   1998      163.01
# 86   1999      166.58
# 87   2000      172.20
# 88   2001      177.07
# 89   2002      179.88
# 90   2003      183.96
# 91   2004      188.88
# 92   2005      195.29
# 93   2006      201.59
# 94   2007      207.34
# 95   2008      215.30
# 96   2009      214.54
# 97   2010      218.06
# 98   2011      224.94
# 99   2012      229.59
# ...

# %% [markdown]
# Data Cleaning - Step 3

# %%
# Create a list of the columns to drop
drop_categories = ['0-75%_of_poverty_wages', '75-100%_of_poverty_wages', '100-125%_of_poverty_wages', '125-200%_of_poverty_wages', \
          '200-300%_of_poverty_wages', 'men_0-75%_of_poverty_wages', 'men_75-100%_of_poverty_wages', \
          'men_100-125%_of_poverty_wages', 'men_125-200%_of_poverty_wages', 'men_200-300%_of_poverty_wages', \
          'women_0-75%_of_poverty_wages', 'women_75-100%_of_poverty_wages', 'women_100-125%_of_poverty_wages', \
          'women_125-200%_of_poverty_wages', 'women_200-300%_of_poverty_wages']
wage_data = wage_data.drop(columns=drop_categories)

wage_data
# Out:
#     Year  annual_poverty-level_wage  hourly_poverty-level_wage  \
# 49  1973                       4701                       2.26
# 48  1974                       5158                       2.48
# 47  1975                       5595                       2.69
# 46  1976                       5914                       2.84
# 45  1977                       6284                       3.02
# 44  1978                       6718                       3.23
# 43  1979                       7360                       3.54
# 42  1980                       8181                       3.93
# 41  1981                       8956                       4.31
# 40  1982                       9499                       4.57
# 39  1983                       9901                       4.76
# 38  1984                      10317                       4.96
# 37  1985                      10670                       5.13
# 36  1986                      10858                       5.22
# ...

# %% [markdown]
# Data Cleaning - Step 4

# %%
# First, we'll merge inflation and wage together
analysis_df = pd.merge(inflation_data, wage_data, on='Year', how='outer')

analysis_df
# Out:
#     Year  Annual_CPI  annual_poverty-level_wage  hourly_poverty-level_wage  \
# 0   1973       44.40                       4701                       2.26
# 1   1974       49.31                       5158                       2.48
# 2   1975       53.82                       5595                       2.69
# 3   1976       56.91                       5914                       2.84
# 4   1977       60.61                       6284                       3.02
# 5   1978       65.23                       6718                       3.23
# 6   1979       72.58                       7360                       3.54
# 7   1980       82.41                       8181                       3.93
# 8   1981       90.92                       8956                       4.31
# 9   1982       96.50                       9499                       4.57
# 10  1983       99.60                       9901                       4.76
# ...

# %%
# Then, merge this with GDP
analysis_df = pd.merge(analysis_df, gdp_data, on='Year', how='outer')

analysis_df
# Out:
#     Year  Annual_CPI  annual_poverty-level_wage  hourly_poverty-level_wage  \
# 0   1973       44.40                       4701                       2.26
# 1   1974       49.31                       5158                       2.48
# 2   1975       53.82                       5595                       2.69
# 3   1976       56.91                       5914                       2.84
# 4   1977       60.61                       6284                       3.02
# 5   1978       65.23                       6718                       3.23
# 6   1979       72.58                       7360                       3.54
# 7   1980       82.41                       8181                       3.93
# 8   1981       90.92                       8956                       4.31
# 9   1982       96.50                       9499                       4.57
# 10  1983       99.60                       9901                       4.76
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %% [markdown]
# Data Limitations:
#
# Validity of the data: This concern applies to both the wage data and inflation data, but more so to the wage data, because we know the inflation data comes from the Bureau of Labor Statistics, which is quite reputable. However, we don't know much about Economic Policy Institute’s State of Working America Data Library. At first glance the data appears valid, and we have no outstanding reason to assume it's not, so this isn't a huge concern. But it is something to think about because if there is invalid data then it could throw off the relationships we found and mean our findings are flawed.
#
# Missing relevant data: It's very possible, almost certain in fact, that we are missing some relevant inputs. There are so many things that likely affect GDP. Industry statistics, political atmosphere, crime rates, urban vs. rural population, etc. there are an infinite number of statistics that go into looking at GDP, and here we're looking at just a few. Our data is limited, by nature of the fact that it does not represent everything. That means we have to be careful about taking our findings as fact, because there's a lot of other factors in play.
#
# Limited time frame: 1973-2021 is a reasonably long timespan, but it also misses a lot of events in American history. We just couldn't find data going that far back, so we worked with what we found. But it's something to consider.
